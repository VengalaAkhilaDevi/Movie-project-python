# %%
'''Movie genre project'''


import json
def Horror():
    movies={"Tumbbad":"8.5", "The Blue Elephant":"8.2", "Shaun of the Dead":"7.9", "I Saw the Devil":"7.8","Get Out (I)":"8.2","What We Do in the Shadows":"7.5",
            "Stree":"7.6","Train to Busan":"7.5","Mirror 1":"6.5","The Conjuring":"8.5"}
    return movies

def Comedy():
    movies={"Ted":"8.4","Life Is Beautiful":"8.5","The Intouchables ":"8.6","Trouble (I) ":"5.9","Love and Monsters (I)":"7.0","The Gentlemen":"7.9",
            "Riders of Justice ":"8.6","Knives Out":"7.0","Soul ":"8.5","Baywatch":"5.6"}
    return movies

def Scifi():
    movies={"Army of the Dead ":"5.8","Tenet":"7.8","Godzilla vs. Kong":"7.9","Avengers: Endgame ":"8.4","Thor: Ragnarok ":"8.0","Interstellar ":"8.6",
            "Inception ":"8.8","Guardians of the Galaxy ":"8.4","Blade Runner 2049":"6.5","The Matrix":"8.3"}
    return movies

def Crime():
    movies={"Cruella ":"7.4","Wrath of Man ":"7.2","Spiral ":"6.2","The Woman in the Window ":"7.2","Promising Young Woman":"7.7","The Godfather":"9.2",
            "Joker ":"8.5","Knives Out":"8.0","The Dry ":"7.0","The Dark Knight ":"9.0"}
    return movies

def Drama():
    movies={"Raya and the Last Dragon ":"7.4","The Mitchells vs the Machines ":"7.8","Blue Miracle ":"8.0","The Goonies":"7.8","Tom and Jerry":"7.9",
            "The Princess Bride":"8.1","The Mighty Ducks ":"6.6","Harry Potter and the Prisoner of Azkaban":"7.9","Stardust":"7.9","Aladdin ":"6.9"}
    return movies

while True:
    dict={}
    print(" Enter 'H' for Horror movies")
    print(" Enter 'C' for Comedy movies")
    print(" Enter 'S' for Sci-Fi movies")
    print(" Enter 'c' for Crime movies")
    print(" Enter 'D' for Drama")
    print(" Enter 'Q' for Quit")
    a=input("")
    if a!='Q':
        if a=='H':
            dict=Horror()
            print(json.dumps(dict, indent=4))
        elif a=='C':
            dict=Comedy()
            print(json.dumps(dict, indent=4))
        elif a=='S':
            dict=Scifi()
            print(json.dumps(dict, indent=4))
        elif a=='c':
            dict=Crime()
            print(json.dumps(dict, indent=4))
        elif a=='D':
            dict=Drama()
            print(json.dumps(dict, indent=4))
        else:
            print("Please check the character")
    else:
        break
# Out:
#  Enter 'H' for Horror movies
#  Enter 'C' for Comedy movies
#  Enter 'S' for Sci-Fi movies
#  Enter 'c' for Crime movies
#  Enter 'D' for Drama
#  Enter 'Q' for Quit
# H
# {
#     "Tumbbad": "8.5",
#     "The Blue Elephant": "8.2",
#     "Shaun of the Dead": "7.9",
#     "I Saw the Devil": "7.8",
#     "Get Out (I)": "8.2",
#     "What We Do in the Shadows": "7.5",
#     "Stree": "7.6",
#     "Train to Busan": "7.5",
#     "Mirror 1": "6.5",
#     "The Conjuring": "8.5"
# }
#  Enter 'H' for Horror movies
#  Enter 'C' for Comedy movies
#  Enter 'S' for Sci-Fi movies
#  Enter 'c' for Crime movies
#  Enter 'D' for Drama
#  Enter 'Q' for Quit
# C
# {
#     "Ted": "8.4",
#     "Life Is Beautiful": "8.5",
#     "The Intouchables ": "8.6",
#     "Trouble (I) ": "5.9",
#     "Love and Monsters (I)": "7.0",
#     "The Gentlemen": "7.9",
#     "Riders of Justice ": "8.6",
#     "Knives Out": "7.0",
#     "Soul ": "8.5",
#     "Baywatch": "5.6"
# }
#  Enter 'H' for Horror movies
# ...
